# %%
import pandas as pd
import csv
import numpy as np
import os
from google.colab import drive
import matplotlib.pyplot as plt
import re
import sys
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, explained_variance_score
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from scipy.stats import wasserstein_distance
from sklearn.ensemble import AdaBoostRegressor


drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
from scipy.stats import wasserstein_distance
import numpy as np
import pandas as pd
import random

P = -1.56 + np.random.normal(4, 0.2, 1000)
Q1 = -1.56 + np.random.normal(-4, 0.2, 1000)
# Q2 = -1.56 + np.random.normal(8, 0.2, 1000)

print(wasserstein_distance(P, Q1))
random.shuffle(Q1)
print(wasserstein_distance(P, Q1))
# Out:
# 7.993463389398243
# 7.993463389398243

# %%
Q = (4.67) + np.random.normal(5, 0.25, 1000)
C1 = (-1.56) + np.random.normal(-2.8, 0.2, 1000)
I = (3) + np.random.normal(-4, 0.3,1000)
C2 = (-1.54) + np.random.normal(7.2, 0.4,1000)
K = (4) + np.random.normal(-4,0.2,1000)
O = (-1)*C1 + np.random.normal(0,0.1,1000)
F = (-0.5)*C2 + np.random.normal(-1,0.55,1000)
L = (-0.9)*O + np.random.normal(0,0.15,1000)
T = (-0.9)*L + np.random.normal(0,0.15,1000)

df = pd.DataFrame({'Q': Q})
df['C1'] = C1
df['I'] = I
df['C2'] = C2 
df['K'] = K
df['O'] = O
df['F'] = F
df['L'] = L
df['T'] = T

Q = (4.67) + np.random.normal(5, 0.25, 1000)
C1 = (-1.56) + np.random.normal(2.8, 0.2, 1000)
I = (3) + np.random.normal(-4, 0.3,1000)
C2 = (-1.54) + np.random.normal(10.2, 0.4,1000)
K = (4) + np.random.normal(-4,0.2,1000)
O = (-1)*C1 + np.random.normal(0,0.1,1000)
F = (-0.5)*C2 + np.random.normal(-1,0.55,1000)
L = (-0.9)*O + np.random.normal(0,0.15,1000)
T = (-0.9)*L + np.random.normal(0,0.15,1000)

df2 = pd.DataFrame({'Q': Q})
df2['C1'] = C1
df2['I'] = I
df2['C2'] = C2 
df2['K'] = K
df2['O'] = O
df2['F'] = F
df2['L'] = L
df2['T'] = T

# %%
sum = 0
for i in range(0, 8):
  sum = sum + abs(wasserstein_distance(df.iloc[:,i], df2.iloc[:,i]))

sum = sum/8
print(sum)
print(wasserstein_distance(df.iloc[:,8], df2.iloc[:,8]))  
print(wasserstein_distance(df.iloc[:,6], df2.iloc[:,6]))
# Out:
# 4.734466820521762
# 4.534322289246135
# 7.196772159516166

# %%
sum = 0
for i in range(0, 8):
  sum = sum + abs(wasserstein_distance(df.iloc[:,i], df2.iloc[:,i]))

sum = sum/8
print(sum)
print(wasserstein_distance(df.iloc[:,8], df2.iloc[:,8])) 
print(wasserstein_distance(df.iloc[:,6], df2.iloc[:,6]))
# Out:
# 2.5833063394649054
# 4.537201530971953
# 1.4348049763041377

# %% [markdown]
# Wasserstein + Random Forest

# %%
data_train = pd.read_csv("/content/drive/MyDrive/TL_cont_train9.csv")
data_test = pd.read_csv("/content/drive/MyDrive/TL_cont_test9.csv")

df1 = data_train.iloc[:1000]
df2 = data_train.iloc[1000:2000]
df3 = data_train.iloc[2000:3000]
df4 = data_train.iloc[3000:4000]
df5 = data_train.iloc[4000:5000]

# %%
# RF train on data_train and test on data_test

y_train = data_train['T']
X_train = data_train.drop(['T'],axis = 1)
ty_test = data_test['T']
tX_test = data_test.drop(['T'],axis = 1)

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
ay_pred = regressor.predict(tX_test) 
# print(y_pred)
mse = mean_squared_error(ty_test, ay_pred)
print("Mean squared error =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
ay_pred2 = regressor2.predict(tX_test) 
# print(y_pred)
mse = mean_squared_error(ty_test, ay_pred2)
print("Mean squared error using adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
ay_pred3 = y_pred
mse = mean_squared_error(ty_test, ay_pred3)
print("Mean squared error using polyreg =", round(mse, 2))
# Out:
# Mean squared error = 13728298.72
# Mean squared error using adaboost = 33468773.75
# Mean squared error using polyreg = 0.06

# %%
print('Domain 1:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df1['T']
X_train = df1.drop(['T'],axis = 1)

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a1 = y_pred
mse = mean_squared_error(ty_test, a1)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a12 = y_pred
mse = mean_squared_error(ty_test, a12)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a13 = y_pred
mse = mean_squared_error(ty_test, a13)
print("Mean squared error using polyreg =", round(mse, 2))


print('Domain 2:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df2['T']
X_train = df2.drop(['T'],axis = 1)

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a2 = y_pred
mse = mean_squared_error(ty_test, a2)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a22 = y_pred
mse = mean_squared_error(ty_test, a22)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a23 = y_pred
mse = mean_squared_error(ty_test, a23)
print("Mean squared error using polyreg =", round(mse, 2))


print('Domain 3:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df3['T']
X_train = df3.drop(['T'],axis = 1)

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a3 = y_pred
mse = mean_squared_error(ty_test, a3)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a32 = y_pred
mse = mean_squared_error(ty_test, a32)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a33 = y_pred
mse = mean_squared_error(ty_test, a33)
print("Mean squared error using polyreg =", round(mse, 2))


print('Domain 4:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df4['T']
X_train = df4.drop(['T'],axis = 1)

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a4 = y_pred
mse = mean_squared_error(ty_test, a4)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a42 = y_pred
mse = mean_squared_error(ty_test, a42)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a43 = y_pred
mse = mean_squared_error(ty_test, a43)
print("Mean squared error using polyreg =", round(mse, 2))


print('Domain 5:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df5['T']
X_train = df5.drop(['T'],axis = 1)

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a5 = y_pred
mse = mean_squared_error(ty_test, a5)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a52 = y_pred
mse = mean_squared_error(ty_test, a52)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a53 = y_pred
mse = mean_squared_error(ty_test, a53)
print("Mean squared error using polyreg =", round(mse, 2))
# Out:
# Domain 1:
# Mean squared error RF = 603220026.59
# Mean squared error using Adaboost = 598773532.19
# Mean squared error using polyreg = 0.15
# Domain 2:
# Mean squared error RF = 797395923.14
# Mean squared error using Adaboost = 800739411.35
# Mean squared error using polyreg = 1.4
# Domain 3:
# Mean squared error RF = 869911681.67
# Mean squared error using Adaboost = 871876570.49
# Mean squared error using polyreg = 0.31
# Domain 4:
# Mean squared error RF = 215402516.39
# Mean squared error using Adaboost = 224579344.1
# Mean squared error using polyreg = 0.3
# Domain 5:
# Mean squared error RF = 13768091.29
# Mean squared error using Adaboost = 14230513.27
# Mean squared error using polyreg = 0.07

# %%
def shift(df,df2):
 sum = 0
 
 for i in range(0, 21):
  sum = sum + abs(wasserstein_distance(df.iloc[:,i], df2.iloc[:,i]))

 sum = sum/21
 print(sum)
 return sum

# %%
df1 = df1.drop(['T'],axis = 1)
df2 = df2.drop(['T'],axis = 1)
df3 = df3.drop(['T'],axis = 1)
df4 = df4.drop(['T'],axis = 1)
df5 = df5.drop(['T'],axis = 1)
data_test = data_test.drop(['T'],axis = 1)

print("Distance b/w Source Domain 1 and Target Domain:")
s1 = shift(df1,data_test)
print("Distance b/w Source Domain 2 and Target Domain:")
s2 = shift(df2,data_test)
print("Distance b/w Source Domain 3 and Target Domain:")
s3 = shift(df3,data_test)
print("Distance b/w Source Domain 4 and Target Domain:")
s4 = shift(df4,data_test)
print("Distance b/w Source Domain 5 and Target Domain:")
s5 = shift(df5,data_test)
# Out:
# Distance b/w Source Domain 1 and Target Domain:
# 1477.0023734962026
# Distance b/w Source Domain 2 and Target Domain:
# 1686.4716541980147
# Distance b/w Source Domain 3 and Target Domain:
# 1748.6160304533412
# Distance b/w Source Domain 4 and Target Domain:
# 940.8632669551329
# Distance b/w Source Domain 5 and Target Domain:
# 358.88645997530733

# %% [markdown]
# SCTL/Markov Blanket + Wasserstein

# %%
import pandas as pd
import csv
import numpy as np
import os
from google.colab import drive
import matplotlib.pyplot as plt
import re
import sys
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, explained_variance_score
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from scipy.stats import wasserstein_distance


drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_train = pd.read_csv("/content/drive/MyDrive/TL_cont_train9.csv")
data_test = pd.read_csv("/content/drive/MyDrive/TL_cont_test9.csv")

df1 = data_train.iloc[:1000]
df2 = data_train.iloc[1000:2000]
df3 = data_train.iloc[2000:3000]
df4 = data_train.iloc[3000:4000]
df5 = data_train.iloc[4000:5000]

# %%
# RF train on data_train and test on data_test

y_train = data_train['T']
X_train = data_train[['A','B']]
ty_test = data_test['T']
tX_test = data_test[['A','B']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
ay_pred = regressor.predict(tX_test) 
# print(y_pred)
mse = mean_squared_error(ty_test, ay_pred)
print("Mean squared error =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
ay_pred2 = regressor2.predict(tX_test) 
# print(y_pred)
mse = mean_squared_error(ty_test, ay_pred2)
print("Mean squared error using adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
ay_pred3 = y_pred
mse = mean_squared_error(ty_test, ay_pred3)
print("Mean squared error using polyreg =", round(mse, 2))
# Out:
# Mean squared error = 12886469.44
# Mean squared error using adaboost = 33468773.75
# Mean squared error using polyreg = 0.06

# %%
print('Domain 1:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df1['T']
X_train = df1[['A','B']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a1 = y_pred
mse = mean_squared_error(ty_test, a1)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a12 = y_pred
mse = mean_squared_error(ty_test, a12)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a13 = y_pred
mse = mean_squared_error(ty_test, a13)
print("Mean squared error using polyreg =", round(mse, 2))

print('Domain 2:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df2['T']
X_train = df2[['A','B']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a2 = y_pred
mse = mean_squared_error(ty_test, a2)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a22 = y_pred
mse = mean_squared_error(ty_test, a22)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a23 = y_pred
mse = mean_squared_error(ty_test, a23)
print("Mean squared error using polyreg =", round(mse, 2))

print('Domain 3:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df3['T']
X_train = df3[['A','B']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a3 = y_pred
mse = mean_squared_error(ty_test, a3)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a32 = y_pred
mse = mean_squared_error(ty_test, a32)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a33 = y_pred
mse = mean_squared_error(ty_test, a33)
print("Mean squared error using polyreg =", round(mse, 2))

print('Domain 4:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df4['T']
X_train = df4[['A','B']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a4 = y_pred
mse = mean_squared_error(ty_test, a4)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a42 = y_pred
mse = mean_squared_error(ty_test, a42)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a43 = y_pred
mse = mean_squared_error(ty_test, a43)
print("Mean squared error using polyreg =", round(mse, 2))

print('Domain 5:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df5['T']
X_train = df5[['A','B']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a5 = y_pred
mse = mean_squared_error(ty_test, a5)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a52 = y_pred
mse = mean_squared_error(ty_test, a52)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a53 = y_pred
mse = mean_squared_error(ty_test, a53)
print("Mean squared error using polyreg =", round(mse, 2))
# Out:
# Domain 1:
# Mean squared error RF = 594857867.06
# Mean squared error using Adaboost = 618186169.59
# Mean squared error using polyreg = 0.06
# Domain 2:
# Mean squared error RF = 792540961.54
# Mean squared error using Adaboost = 798727934.24
# Mean squared error using polyreg = 0.96
# Domain 3:
# Mean squared error RF = 862243912.09
# Mean squared error using Adaboost = 863963773.08
# Mean squared error using polyreg = 0.07
# Domain 4:
# Mean squared error RF = 213519841.24
# Mean squared error using Adaboost = 221654730.33
# Mean squared error using polyreg = 0.24
# Domain 5:
# Mean squared error RF = 12935682.52
# Mean squared error using Adaboost = 16425770.51
# Mean squared error using polyreg = 0.06

# %%
def shift(df,df2):
 sum = 0
 
 for i in range(0, 21):
  sum = sum + abs(wasserstein_distance(df.iloc[:,i], df2.iloc[:,i]))

 sum = sum/21
 print(sum)
 return sum

# %%
df1 = df1.drop(['T'],axis = 1)
df2 = df2.drop(['T'],axis = 1)
df3 = df3.drop(['T'],axis = 1)
df4 = df4.drop(['T'],axis = 1)
df5 = df5.drop(['T'],axis = 1)
data_test = data_test.drop(['T'],axis = 1)

print("Distance b/w Source Domain 1 and Target Domain:")
s1 = shift(df1,data_test)
print("Distance b/w Source Domain 2 and Target Domain:")
s2 = shift(df2,data_test)
print("Distance b/w Source Domain 3 and Target Domain:")
s3 = shift(df3,data_test)
print("Distance b/w Source Domain 4 and Target Domain:")
s4 = shift(df4,data_test)
print("Distance b/w Source Domain 5 and Target Domain:")
s5 = shift(df5,data_test)
# Out:
# Distance b/w Source Domain 1 and Target Domain:
# 1477.0023734962026
# Distance b/w Source Domain 2 and Target Domain:
# 1686.4716541980147
# Distance b/w Source Domain 3 and Target Domain:
# 1748.6160304533412
# Distance b/w Source Domain 4 and Target Domain:
# 940.8632669551329
# Distance b/w Source Domain 5 and Target Domain:
# 358.88645997530733

# %% [markdown]
# Using Data Generation from Stabilized Regression paper

# %%
dx = pd.read_csv("/content/drive/MyDrive/lx.csv")
dy = pd.read_csv("/content/drive/MyDrive/ly.csv")
df = pd.concat((dx, dy), axis=1)

data_train = df[1:5000]
data_test = df[5001:6000]
df1 = data_train.iloc[:1000]
df2 = data_train.iloc[1000:2000]
df3 = data_train.iloc[2000:3000]
df4 = data_train.iloc[3000:4000]
df5 = data_train.iloc[4000:5000]

# %% [markdown]
# 1. Weighted RF/Adaboost/Polyreg

# %%
# RF train on data_train and test on data_test

y_train = data_train['x']
X_train = data_train.drop(['x'],axis = 1)
ty_test = data_test['x']
tX_test = data_test.drop(['x'],axis = 1)

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
ay_pred = regressor.predict(tX_test) 
# print(y_pred)
mse = mean_squared_error(ty_test, ay_pred)
print("Mean squared error =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
ay_pred2 = regressor2.predict(tX_test) 
# print(y_pred)
mse = mean_squared_error(ty_test, ay_pred2)
print("Mean squared error using adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
ay_pred3 = y_pred
mse = mean_squared_error(ty_test, ay_pred3)
print("Mean squared error using polyreg =", round(mse, 2))
# Out:
# Mean squared error = 8.18
# Mean squared error using adaboost = 9.37
# Mean squared error using polyreg = 1.29

# %%
print('Domain 1:')
y_train = df1['x']
X_train = df1.drop(['x'],axis = 1)
regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a1 = y_pred
mse = mean_squared_error(ty_test, a1)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a12 = y_pred
mse = mean_squared_error(ty_test, a12)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a13 = y_pred
mse = mean_squared_error(ty_test, a13)
print("Mean squared error using polyreg =", round(mse, 2))

print('Domain 2:')
y_train = df2['x']
X_train = df2.drop(['x'],axis = 1)

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a2 = y_pred
mse = mean_squared_error(ty_test, a2)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a22 = y_pred
mse = mean_squared_error(ty_test, a22)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a23 = y_pred
mse = mean_squared_error(ty_test, a23)
print("Mean squared error using polyreg =", round(mse, 2))

print('Domain 3:')
y_train = df3['x']
X_train = df3.drop(['x'],axis = 1)

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a3 = y_pred
mse = mean_squared_error(ty_test, a3)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a32 = y_pred
mse = mean_squared_error(ty_test, a32)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a33 = y_pred
mse = mean_squared_error(ty_test, a33)
print("Mean squared error using polyreg =", round(mse, 2))

print('Domain 4:')
y_train = df4['x']
X_train = df4.drop(['x'],axis = 1)

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a4 = y_pred
mse = mean_squared_error(ty_test, a4)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a42 = y_pred
mse = mean_squared_error(ty_test, a42)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a43 = y_pred
mse = mean_squared_error(ty_test, a43)
print("Mean squared error using polyreg =", round(mse, 2))

print('Domain 5:')
y_train = df5['x']
X_train = df5.drop(['x'],axis = 1)

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a5 = y_pred
mse = mean_squared_error(ty_test, a5)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a52 = y_pred
mse = mean_squared_error(ty_test, a52)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a53 = y_pred
mse = mean_squared_error(ty_test, a53)
print("Mean squared error using polyreg =", round(mse, 2))
# Out:
# Domain 1:
# Mean squared error RF = 8.99
# Mean squared error using Adaboost = 9.74
# Mean squared error using polyreg = 1.39
# Domain 2:
# Mean squared error RF = 8.61
# Mean squared error using Adaboost = 9.16
# Mean squared error using polyreg = 1.09
# Domain 3:
# Mean squared error RF = 9.02
# Mean squared error using Adaboost = 9.56
# Mean squared error using polyreg = 1.52
# Domain 4:
# Mean squared error RF = 9.52
# Mean squared error using Adaboost = 9.76
# Mean squared error using polyreg = 1.67
# Domain 5:
# Mean squared error RF = 9.38
# Mean squared error using Adaboost = 9.84
# Mean squared error using polyreg = 1.27

# %%
def shift(df,df2):
 sum = 0
 
 for i in range(0, 21):
  sum = sum + abs(wasserstein_distance(df.iloc[:,i], df2.iloc[:,i]))

 sum = sum/21
 print(sum)
 return sum
df1 = df1.drop(['x'],axis = 1)
df2 = df2.drop(['x'],axis = 1)
df3 = df3.drop(['x'],axis = 1)
df4 = df4.drop(['x'],axis = 1)
df5 = df5.drop(['x'],axis = 1)
data_test = data_test.drop(['x'],axis = 1)

print("Distance b/w Source Domain 1 and Target Domain:")
s1 = shift(df1,data_test)
print("Distance b/w Source Domain 2 and Target Domain:")
s2 = shift(df2,data_test)
print("Distance b/w Source Domain 3 and Target Domain:")
s3 = shift(df3,data_test)
print("Distance b/w Source Domain 4 and Target Domain:")
s4 = shift(df4,data_test)
print("Distance b/w Source Domain 5 and Target Domain:")
s5 = shift(df5,data_test)

# Percentage
sum = 1/s1 + 1/s2 + 1/s3 + 1/s4 + 1/s5
ns1 = (1/s1)/sum
print(ns1)
ns2 = (1/s2)/sum
print(ns2)
ns3 = (1/s3)/sum
print(ns3)
ns4 = (1/s4)/sum
print(ns4)
ns5 = (1/s5)/sum
print(ns5)
# Out:
# Distance b/w Source Domain 1 and Target Domain:
# 2.560225813783573
# Distance b/w Source Domain 2 and Target Domain:
# 2.5026473177713284
# Distance b/w Source Domain 3 and Target Domain:
# 2.53130613133788
# Distance b/w Source Domain 4 and Target Domain:
# 2.5273725886067577
# Distance b/w Source Domain 5 and Target Domain:
# 2.5356711171445445
# 0.197741221282889
# 0.20229066060669768
# 0.2000003764499103
# 0.20031165229050174
# 0.19965608937000126

# %% [markdown]
# 2. Weighted MB using RF/Ada/Polyreg

# %%
# RF train on data_train and test on data_test

y_train = data_train['x']
X_train = data_train[['V6','V16','V12','V21','V8','V14','V18']]
ty_test = data_test['x']
tX_test = data_test[['V6','V16','V12','V21','V8','V14','V18']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
ay_pred = regressor.predict(tX_test) 
# print(y_pred)
mse = mean_squared_error(ty_test, ay_pred)
print("Mean squared error =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
ay_pred2 = regressor2.predict(tX_test) 
# print(y_pred)
mse = mean_squared_error(ty_test, ay_pred2)
print("Mean squared error using adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
ay_pred3 = y_pred
mse = mean_squared_error(ty_test, ay_pred3)
print("Mean squared error using polyreg =", round(mse, 2))
# Out:
# Mean squared error = 8.09
# Mean squared error using adaboost = 9.07
# Mean squared error using polyreg = 1.53

# %%
# 6,8,12,14,16,18,21
print('Domain 1:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['x'],axis = 1), df1['x'],test_size=0.2)
y_train = df1['x']
X_train = df1[['V6','V16','V12','V21','V8','V14','V18']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a1 = y_pred
mse = mean_squared_error(ty_test, a1)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a12 = y_pred
mse = mean_squared_error(ty_test, a12)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a13 = y_pred
mse = mean_squared_error(ty_test, a13)
print("Mean squared error using polyreg =", round(mse, 2))

print('Domain 2:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df2['x']
X_train = df2[['V6','V16','V12','V21','V8','V14','V18']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a2 = y_pred
mse = mean_squared_error(ty_test, a2)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a22 = y_pred
mse = mean_squared_error(ty_test, a22)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a23 = y_pred
mse = mean_squared_error(ty_test, a23)
print("Mean squared error using polyreg =", round(mse, 2))

print('Domain 3:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df3['x']
X_train = df3[['V6','V16','V12','V21','V8','V14','V18']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a3 = y_pred
mse = mean_squared_error(ty_test, a3)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a32 = y_pred
mse = mean_squared_error(ty_test, a32)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a33 = y_pred
mse = mean_squared_error(ty_test, a33)
print("Mean squared error using polyreg =", round(mse, 2))

print('Domain 4:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df4['x']
X_train = df4[['V6','V16','V12','V21','V8','V14','V18']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a4 = y_pred
mse = mean_squared_error(ty_test, a4)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a42 = y_pred
mse = mean_squared_error(ty_test, a42)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a43 = y_pred
mse = mean_squared_error(ty_test, a43)
print("Mean squared error using polyreg =", round(mse, 2))

print('Domain 5:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df5['x']
X_train = df5[['V6','V16','V12','V21','V8','V14','V18']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a5 = y_pred
mse = mean_squared_error(ty_test, a5)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a52 = y_pred
mse = mean_squared_error(ty_test, a52)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a53 = y_pred
mse = mean_squared_error(ty_test, a53)
print("Mean squared error using polyreg =", round(mse, 2))
# Out:
# Domain 1:
# Mean squared error RF = 8.83
# Mean squared error using Adaboost = 9.51
# Mean squared error using polyreg = 1.55
# Domain 2:
# Mean squared error RF = 8.4
# Mean squared error using Adaboost = 9.18
# Mean squared error using polyreg = 1.48
# Domain 3:
# Mean squared error RF = 8.85
# Mean squared error using Adaboost = 9.5
# Mean squared error using polyreg = 1.58
# Domain 4:
# Mean squared error RF = 9.28
# Mean squared error using Adaboost = 9.88
# Mean squared error using polyreg = 1.6
# Domain 5:
# Mean squared error RF = 9.31
# Mean squared error using Adaboost = 9.75
# Mean squared error using polyreg = 1.51

# %%
def shift(df,df2):
 sum = 0
 
 for i in range(0, 21):
  sum = sum + abs(wasserstein_distance(df.iloc[:,i], df2.iloc[:,i]))

 sum = sum/21
 print(sum)
 return sum
df1 = df1.drop(['x'],axis = 1)
df2 = df2.drop(['x'],axis = 1)
df3 = df3.drop(['x'],axis = 1)
df4 = df4.drop(['x'],axis = 1)
df5 = df5.drop(['x'],axis = 1)
data_test = data_test.drop(['x'],axis = 1)

print("Distance b/w Source Domain 1 and Target Domain:")
s1 = shift(df1,data_test)
print("Distance b/w Source Domain 2 and Target Domain:")
s2 = shift(df2,data_test)
print("Distance b/w Source Domain 3 and Target Domain:")
s3 = shift(df3,data_test)
print("Distance b/w Source Domain 4 and Target Domain:")
s4 = shift(df4,data_test)
print("Distance b/w Source Domain 5 and Target Domain:")
s5 = shift(df5,data_test)

# Percentage
sum = 1/s1 + 1/s2 + 1/s3 + 1/s4 + 1/s5
ns1 = (1/s1)/sum
print(ns1)
ns2 = (1/s2)/sum
print(ns2)
ns3 = (1/s3)/sum
print(ns3)
ns4 = (1/s4)/sum
print(ns4)
ns5 = (1/s5)/sum
print(ns5)
# Out:
# Distance b/w Source Domain 1 and Target Domain:
# 2.560225813783573
# Distance b/w Source Domain 2 and Target Domain:
# 2.5026473177713284
# Distance b/w Source Domain 3 and Target Domain:
# 2.53130613133788
# Distance b/w Source Domain 4 and Target Domain:
# 2.5273725886067577
# Distance b/w Source Domain 5 and Target Domain:
# 2.5356711171445445
# 0.197741221282889
# 0.20229066060669768
# 0.2000003764499103
# 0.20031165229050174
# 0.19965608937000126

# %% [markdown]
# Setting 10: CAUSAL STRUCTURE CHANGED

# %%
data_train = pd.read_csv("/content/drive/MyDrive/TL_cont_train10.csv")
data_test = pd.read_csv("/content/drive/MyDrive/TL_cont_test10.csv")

df1 = data_train.iloc[:1000]
df2 = data_train.iloc[1000:2000]
df3 = data_train.iloc[2000:3000]
df4 = data_train.iloc[3000:4000]
df5 = data_train.iloc[4000:5000]

# %% [markdown]
# 1. Weighted RF/Ada/Polyreg

# %%
# RF train on data_train and test on data_test

y_train = data_train['T']
X_train = data_train.drop(['T'],axis = 1)
ty_test = data_test['T']
tX_test = data_test.drop(['T'],axis = 1)

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
ay_pred = regressor.predict(tX_test) 
# print(y_pred)
mse = mean_squared_error(ty_test, ay_pred)
print("Mean squared error =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
ay_pred2 = regressor2.predict(tX_test) 
# print(y_pred)
mse = mean_squared_error(ty_test, ay_pred2)
print("Mean squared error using adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
ay_pred3 = y_pred
mse = mean_squared_error(ty_test, ay_pred3)
print("Mean squared error using polyreg =", round(mse, 2))
# Out:
# Mean squared error = 12455.18
# Mean squared error using adaboost = 57897.86
# Mean squared error using polyreg = 0.07

# %%
print('Domain 1:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df1['T']
X_train = df1.drop(['T'],axis = 1)

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a1 = y_pred
mse = mean_squared_error(ty_test, a1)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a12 = y_pred
mse = mean_squared_error(ty_test, a12)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a13 = y_pred
mse = mean_squared_error(ty_test, a13)
print("Mean squared error using polyreg =", round(mse, 2))


print('Domain 2:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df2['T']
X_train = df2.drop(['T'],axis = 1)

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a2 = y_pred
mse = mean_squared_error(ty_test, a2)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a22 = y_pred
mse = mean_squared_error(ty_test, a22)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a23 = y_pred
mse = mean_squared_error(ty_test, a23)
print("Mean squared error using polyreg =", round(mse, 2))


print('Domain 3:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df3['T']
X_train = df3.drop(['T'],axis = 1)

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a3 = y_pred
mse = mean_squared_error(ty_test, a3)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a32 = y_pred
mse = mean_squared_error(ty_test, a32)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a33 = y_pred
mse = mean_squared_error(ty_test, a33)
print("Mean squared error using polyreg =", round(mse, 2))


print('Domain 4:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df4['T']
X_train = df4.drop(['T'],axis = 1)

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a4 = y_pred
mse = mean_squared_error(ty_test, a4)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a42 = y_pred
mse = mean_squared_error(ty_test, a42)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a43 = y_pred
mse = mean_squared_error(ty_test, a43)
print("Mean squared error using polyreg =", round(mse, 2))


print('Domain 5:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df5['T']
X_train = df5.drop(['T'],axis = 1)

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a5 = y_pred
mse = mean_squared_error(ty_test, a5)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a52 = y_pred
mse = mean_squared_error(ty_test, a52)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a53 = y_pred
mse = mean_squared_error(ty_test, a53)
print("Mean squared error using polyreg =", round(mse, 2))
# Out:
# Domain 1:
# Mean squared error RF = 615363.49
# Mean squared error using Adaboost = 626891.99
# Mean squared error using polyreg = 0.09
# Domain 2:
# Mean squared error RF = 684706.58
# Mean squared error using Adaboost = 777868.12
# Mean squared error using polyreg = 0.33
# Domain 3:
# Mean squared error RF = 957598.89
# Mean squared error using Adaboost = 1153855.41
# Mean squared error using polyreg = 0.07
# Domain 4:
# Mean squared error RF = 15204.27
# Mean squared error using Adaboost = 20337.45
# Mean squared error using polyreg = 0.07
# Domain 5:
# Mean squared error RF = 3902888.9
# Mean squared error using Adaboost = 3828779.89
# Mean squared error using polyreg = 0.07

# %%
def shift(df,df2):
 sum = 0
 
 for i in range(0, 21):
  sum = sum + abs(wasserstein_distance(df.iloc[:,i], df2.iloc[:,i]))

 sum = sum/21
 print(sum)
 return sum
df1 = df1.drop(['T'],axis = 1)
df2 = df2.drop(['T'],axis = 1)
df3 = df3.drop(['T'],axis = 1)
df4 = df4.drop(['T'],axis = 1)
df5 = df5.drop(['T'],axis = 1)
data_test = data_test.drop(['T'],axis = 1)

print("Distance b/w Source Domain 1 and Target Domain:")
s1 = shift(df1,data_test)
print("Distance b/w Source Domain 2 and Target Domain:")
s2 = shift(df2,data_test)
print("Distance b/w Source Domain 3 and Target Domain:")
s3 = shift(df3,data_test)
print("Distance b/w Source Domain 4 and Target Domain:")
s4 = shift(df4,data_test)
print("Distance b/w Source Domain 5 and Target Domain:")
s5 = shift(df5,data_test)

# Percentage
sum = 1/s1 + 1/s2 + 1/s3 + 1/s4 + 1/s5
ns1 = (1/s1)/sum
print(ns1)
ns2 = (1/s2)/sum
print(ns2)
ns3 = (1/s3)/sum
print(ns3)
ns4 = (1/s4)/sum
print(ns4)
ns5 = (1/s5)/sum
print(ns5)
# Out:
# Distance b/w Source Domain 1 and Target Domain:
# 188.28191411586764
# Distance b/w Source Domain 2 and Target Domain:
# 190.4682162308722
# Distance b/w Source Domain 3 and Target Domain:
# 188.06027163028773
# Distance b/w Source Domain 4 and Target Domain:
# 56.29562252607043
# Distance b/w Source Domain 5 and Target Domain:
# 251.7508502347376
# 0.14120083116691243
# 0.13958004801511126
# 0.14136724644917528
# 0.4722492011620618
# 0.10560267320673919

# %% [markdown]
# 2. Weighted MB + RF/Ada/Polyreg

# %%
# RF train on data_train and test on data_test

y_train = data_train['T']
X_train = data_train[['A','B']]
ty_test = data_test['T']
tX_test = data_test[['A','B']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
ay_pred = regressor.predict(tX_test) 
# print(y_pred)
mse = mean_squared_error(ty_test, ay_pred)
print("Mean squared error =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
ay_pred2 = regressor2.predict(tX_test) 
# print(y_pred)
mse = mean_squared_error(ty_test, ay_pred2)
print("Mean squared error using adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
ay_pred3 = y_pred
mse = mean_squared_error(ty_test, ay_pred3)
print("Mean squared error using polyreg =", round(mse, 2))
# Out:
# Mean squared error = 40678.54
# Mean squared error using adaboost = 64654.63
# Mean squared error using polyreg = 0.07

# %%
print('Domain 1:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df1['T']
X_train = df1[['A','B']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a1 = y_pred
mse = mean_squared_error(ty_test, a1)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a12 = y_pred
mse = mean_squared_error(ty_test, a12)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a13 = y_pred
mse = mean_squared_error(ty_test, a13)
print("Mean squared error using polyreg =", round(mse, 2))

print('Domain 2:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df2['T']
X_train = df2[['A','B']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a2 = y_pred
mse = mean_squared_error(ty_test, a2)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a22 = y_pred
mse = mean_squared_error(ty_test, a22)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a23 = y_pred
mse = mean_squared_error(ty_test, a23)
print("Mean squared error using polyreg =", round(mse, 2))

print('Domain 3:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df3['T']
X_train = df3[['A','B']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a3 = y_pred
mse = mean_squared_error(ty_test, a3)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a32 = y_pred
mse = mean_squared_error(ty_test, a32)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a33 = y_pred
mse = mean_squared_error(ty_test, a33)
print("Mean squared error using polyreg =", round(mse, 2))

print('Domain 4:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df4['T']
X_train = df4[['A','B']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a4 = y_pred
mse = mean_squared_error(ty_test, a4)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a42 = y_pred
mse = mean_squared_error(ty_test, a42)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a43 = y_pred
mse = mean_squared_error(ty_test, a43)
print("Mean squared error using polyreg =", round(mse, 2))

print('Domain 5:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df5['T']
X_train = df5[['A','B']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a5 = y_pred
mse = mean_squared_error(ty_test, a5)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a52 = y_pred
mse = mean_squared_error(ty_test, a52)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a53 = y_pred
mse = mean_squared_error(ty_test, a53)
print("Mean squared error using polyreg =", round(mse, 2))
# Out:
# Domain 1:
# Mean squared error RF = 287051.29
# Mean squared error using Adaboost = 269371.26
# Mean squared error using polyreg = 0.07
# Domain 2:
# Mean squared error RF = 526505.41
# Mean squared error using Adaboost = 758208.27
# Mean squared error using polyreg = 0.07
# Domain 3:
# Mean squared error RF = 746593.21
# Mean squared error using Adaboost = 1209544.67
# Mean squared error using polyreg = 0.07
# Domain 4:
# Mean squared error RF = 64756.9
# Mean squared error using Adaboost = 65216.19
# Mean squared error using polyreg = 0.09
# Domain 5:
# Mean squared error RF = 3541149.89
# Mean squared error using Adaboost = 4445882.2
# Mean squared error using polyreg = 0.2

# %%
def shift(df,df2):
 sum = 0
 
 for i in range(0, 21):
  sum = sum + abs(wasserstein_distance(df.iloc[:,i], df2.iloc[:,i]))

 sum = sum/21
 print(sum)
 return sum
df1 = df1.drop(['T'],axis = 1)
df2 = df2.drop(['T'],axis = 1)
df3 = df3.drop(['T'],axis = 1)
df4 = df4.drop(['T'],axis = 1)
df5 = df5.drop(['T'],axis = 1)
data_test = data_test.drop(['T'],axis = 1)

print("Distance b/w Source Domain 1 and Target Domain:")
s1 = shift(df1,data_test)
print("Distance b/w Source Domain 2 and Target Domain:")
s2 = shift(df2,data_test)
print("Distance b/w Source Domain 3 and Target Domain:")
s3 = shift(df3,data_test)
print("Distance b/w Source Domain 4 and Target Domain:")
s4 = shift(df4,data_test)
print("Distance b/w Source Domain 5 and Target Domain:")
s5 = shift(df5,data_test)

# Percentage
sum = 1/s1 + 1/s2 + 1/s3 + 1/s4 + 1/s5
ns1 = (1/s1)/sum
print(ns1)
ns2 = (1/s2)/sum
print(ns2)
ns3 = (1/s3)/sum
print(ns3)
ns4 = (1/s4)/sum
print(ns4)
ns5 = (1/s5)/sum
print(ns5)
# Out:
# Distance b/w Source Domain 1 and Target Domain:
# 188.28191411586764
# Distance b/w Source Domain 2 and Target Domain:
# 190.4682162308722
# Distance b/w Source Domain 3 and Target Domain:
# 188.06027163028773
# Distance b/w Source Domain 4 and Target Domain:
# 56.29562252607043
# Distance b/w Source Domain 5 and Target Domain:
# 251.7508502347376
# 0.14120083116691243
# 0.13958004801511126
# 0.14136724644917528
# 0.4722492011620618
# 0.10560267320673919

# %% [markdown]
# 3. Weighted ICP + RF/Ada/Polyreg

# %%
# RF train on data_train and test on data_test

y_train = data_train['T']
X_train = data_train[['S','E','B','N','A','P','V','D']]
ty_test = data_test['T']
tX_test = data_test[['S','E','B','N','A','P','V','D']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
ay_pred = regressor.predict(tX_test) 
# print(y_pred)
mse = mean_squared_error(ty_test, ay_pred)
print("Mean squared error =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
ay_pred2 = regressor2.predict(tX_test) 
# print(y_pred)
mse = mean_squared_error(ty_test, ay_pred2)
print("Mean squared error using adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
ay_pred3 = y_pred
mse = mean_squared_error(ty_test, ay_pred3)
print("Mean squared error using polyreg =", round(mse, 2))
# Out:
# Mean squared error = 13399.38
# Mean squared error using adaboost = 56667.7
# Mean squared error using polyreg = 0.07

# %%
print('Domain 1:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df1['T']
X_train = df1[['S','E','B','N','A','P','V','D']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a1 = y_pred
mse = mean_squared_error(ty_test, a1)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a12 = y_pred
mse = mean_squared_error(ty_test, a12)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a13 = y_pred
mse = mean_squared_error(ty_test, a13)
print("Mean squared error using polyreg =", round(mse, 2))

print('Domain 2:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df2['T']
X_train = df2[['S','E','B','N','A','P','V','D']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a2 = y_pred
mse = mean_squared_error(ty_test, a2)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a22 = y_pred
mse = mean_squared_error(ty_test, a22)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a23 = y_pred
mse = mean_squared_error(ty_test, a23)
print("Mean squared error using polyreg =", round(mse, 2))

print('Domain 3:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df3['T']
X_train = df3[['S','E','B','N','A','P','V','D']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a3 = y_pred
mse = mean_squared_error(ty_test, a3)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a32 = y_pred
mse = mean_squared_error(ty_test, a32)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a33 = y_pred
mse = mean_squared_error(ty_test, a33)
print("Mean squared error using polyreg =", round(mse, 2))

print('Domain 4:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df4['T']
X_train = df4[['S','E','B','N','A','P','V','D']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a4 = y_pred
mse = mean_squared_error(ty_test, a4)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a42 = y_pred
mse = mean_squared_error(ty_test, a42)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a43 = y_pred
mse = mean_squared_error(ty_test, a43)
print("Mean squared error using polyreg =", round(mse, 2))

print('Domain 5:')
# X_train,X_test,y_train,y_test = train_test_split(df1.drop(['T'],axis = 1), df1['T'],test_size=0.2)
y_train = df5['T']
X_train = df5[['S','E','B','N','A','P','V','D']]

regressor = RandomForestRegressor(n_estimators = 1000,random_state=49)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(tX_test) 
# print(y_pred)
a5 = y_pred
mse = mean_squared_error(ty_test, a5)
print("Mean squared error RF =", round(mse, 2))

regressor2 = AdaBoostRegressor(n_estimators=1000, random_state=49)
regressor2.fit(X_train, y_train)
y_pred = regressor2.predict(tX_test) 
# print(y_pred)
a52 = y_pred
mse = mean_squared_error(ty_test, a52)
print("Mean squared error using Adaboost =", round(mse, 2))

degree=1
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X_train,y_train)
y_pred = polyreg.predict(tX_test) 
# print(y_pred)
a53 = y_pred
mse = mean_squared_error(ty_test, a53)
print("Mean squared error using polyreg =", round(mse, 2))
# Out:
# Domain 1:
# Mean squared error RF = 333682.11
# Mean squared error using Adaboost = 261145.86
# Mean squared error using polyreg = 0.07
# Domain 2:
# Mean squared error RF = 586281.13
# Mean squared error using Adaboost = 779166.8
# Mean squared error using polyreg = 0.39
# Domain 3:
# Mean squared error RF = 769343.24
# Mean squared error using Adaboost = 936711.16
# Mean squared error using polyreg = 0.07
# Domain 4:
# Mean squared error RF = 20871.65
# Mean squared error using Adaboost = 27909.14
# Mean squared error using polyreg = 0.09
# Domain 5:
# Mean squared error RF = 3615145.32
# Mean squared error using Adaboost = 4129067.4
# Mean squared error using polyreg = 0.2

# %%
def shift(df,df2):
 sum = 0
 
 for i in range(0, 21):
  sum = sum + abs(wasserstein_distance(df.iloc[:,i], df2.iloc[:,i]))

 sum = sum/21
 print(sum)
 return sum
df1 = df1.drop(['T'],axis = 1)
df2 = df2.drop(['T'],axis = 1)
df3 = df3.drop(['T'],axis = 1)
df4 = df4.drop(['T'],axis = 1)
df5 = df5.drop(['T'],axis = 1)
data_test = data_test.drop(['T'],axis = 1)

print("Distance b/w Source Domain 1 and Target Domain:")
s1 = shift(df1,data_test)
print("Distance b/w Source Domain 2 and Target Domain:")
s2 = shift(df2,data_test)
print("Distance b/w Source Domain 3 and Target Domain:")
s3 = shift(df3,data_test)
print("Distance b/w Source Domain 4 and Target Domain:")
s4 = shift(df4,data_test)
print("Distance b/w Source Domain 5 and Target Domain:")
s5 = shift(df5,data_test)

# Percentage
sum = 1/s1 + 1/s2 + 1/s3 + 1/s4 + 1/s5
ns1 = (1/s1)/sum
print(ns1)
ns2 = (1/s2)/sum
print(ns2)
ns3 = (1/s3)/sum
print(ns3)
ns4 = (1/s4)/sum
print(ns4)
ns5 = (1/s5)/sum
print(ns5)
# Out:
# Distance b/w Source Domain 1 and Target Domain:
# 188.28191411586764
# Distance b/w Source Domain 2 and Target Domain:
# 190.4682162308722
# Distance b/w Source Domain 3 and Target Domain:
# 188.06027163028773
# Distance b/w Source Domain 4 and Target Domain:
# 56.29562252607043
# Distance b/w Source Domain 5 and Target Domain:
# 251.7508502347376
# 0.14120083116691243
# 0.13958004801511126
# 0.14136724644917528
# 0.4722492011620618
# 0.10560267320673919
